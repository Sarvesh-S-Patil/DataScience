# %%
column_names= ['Student_id','First_Name','Last_Name','Regular_Attendance','Standard','Gender','Marks_Scored']

# %%
import pandas as pd

# %%
import random

# %%
import string

# %%
pip install xlwt

# %%
import openpyxl

# %%
rows = int(input("Enter no of rows to be generated : "))
# Out:
# Enter no of rows to be generated : 800

# %%
import numpy as np

# %%
Student_info = [[0 for i in range(7)] for j in range(rows)]

# %%
def Random_Matrix_Generator(rows):
    j=1
    i=0
    while(i<rows):
        student_id=j
        first_name= ''.join(random.choices(string.ascii_lowercase,k=5))
        last_name= ''.join(random.choices(string.ascii_lowercase,k=5))
        regular_attendance=random.choices(['Yes','No'])
        standard= random.choices([1,2,3,4,5,6,7,8,9])
        gender= random.choices(['M','F'])
        marks_scored=random.randint(0,100)
        Student_info[i]= student_id,first_name,last_name,regular_attendance,standard,gender,marks_scored
        
        j+=1
        i+=1
        
        
    return Student_info

# %%
Student_info = Random_Matrix_Generator(rows)

# %%
Student_info_df = pd.DataFrame(Student_info)

# %%
Student_info_df
# Out:
#        0      1      2      3    4    5   6
# 0      1  ulcto  djnfw  [Yes]  [8]  [F]  64
# 1      2  zwngb  qfqmd   [No]  [2]  [F]  61
# 2      3  pnbxk  ybufx   [No]  [5]  [M]  29
# 3      4  cxeac  kgzaw  [Yes]  [8]  [F]  64
# 4      5  xtpjk  zkddc   [No]  [1]  [M]  39
# ..   ...    ...    ...    ...  ...  ...  ..
# 795  796  uhpjz  nlwjr  [Yes]  [2]  [F]  62
# 796  797  lvjkv  vouux   [No]  [1]  [F]  70
# 797  798  krkml  xudti  [Yes]  [5]  [F]  26
# 798  799  oyvan  hevji  [Yes]  [7]  [F]  61
# 799  800  feljy  zevcq   [No]  [2]  [F]  88
#
# [800 rows x 7 columns]

# %%
Student_info_df.columns = column_names

# %%
Student_info_df
# Out:
#      Student_id First_Name Last_Name Regular_Attendance Standard Gender  \
# 0             1      ulcto     djnfw              [Yes]      [8]    [F]
# 1             2      zwngb     qfqmd               [No]      [2]    [F]
# 2             3      pnbxk     ybufx               [No]      [5]    [M]
# 3             4      cxeac     kgzaw              [Yes]      [8]    [F]
# 4             5      xtpjk     zkddc               [No]      [1]    [M]
# ..          ...        ...       ...                ...      ...    ...
# 795         796      uhpjz     nlwjr              [Yes]      [2]    [F]
# 796         797      lvjkv     vouux               [No]      [1]    [F]
# 797         798      krkml     xudti              [Yes]      [5]    [F]
# 798         799      oyvan     hevji              [Yes]      [7]    [F]
# 799         800      feljy     zevcq               [No]      [2]    [F]
#
#      Marks_Scored
# 0              64
# 1              61
# 2              29
# 3              64
# ...

# %%
Student_info_df.to_excel('StudentInfo2.xlsx',sheet_name='student_info')
